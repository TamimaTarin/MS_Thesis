# %% [markdown]
# Image Extraction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os

# %%
def save_images(filename, path):
    if not os.path.exists(path):
        os.makedirs(path)

    vidcap = cv2.VideoCapture(path + "//" + filename)

    # get the number of frames
    n_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))

    # saved frames
    # saved_frames = [0, int(n_frames/3), int(2*n_frames/3), n_frames-1]
    saved_frames = [0, 5,  int(n_frames/3), int(n_frames/2), int(2*n_frames/3), n_frames-1]


    # save the first frame
    for i in range(0, 6):
        vidcap.set(cv2.CAP_PROP_POS_FRAMES, saved_frames[i])
        success, image = vidcap.read()
        dir = None
        image_name = None
        if i == 0 or i == 1 or i== 5:
            dir = os.path.join(path, "..\\images3", filename[0:3], 'neutral').replace("\\","/")
            image_name = filename[0:5]+filename[-5]+'_neutral_'+str(saved_frames[i])+'.jpg'
        else:
            dir = os.path.join(path, "..\\images3", filename[0:3], 'smile').replace("\\","/")
            image_name = filename[0:5]+filename[-5]+'_smile_'+str(saved_frames[i])+'.jpg'

        if not os.path.exists(dir):
            os.makedirs(dir)


        name = os.path.join(dir, image_name).replace("\\","/")
        # print('image', i, 'saved at', name)
        cv2.imwrite(name, image)

# %%
directory = '/content/drive/MyDrive/Msthesis/Dataset/videos'
count = 1

# loop for all video files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".mp4") and filename.__contains__("spontaneous"):
        # save images
        print('\rcount:', count, ', Saving images for', filename, '             ', end='')
        save_images(filename, directory)
        count = count + 1
    # if count > 1:
    #   break
# Out:
# count: 597 , Saving images for 464_spontaneous_smile_4.mp4

# %% [markdown]
# Create Landmark files

# %% [markdown]
# Importing Library

# %%
#loads data from dataset with a path
import os
import cv2


#landmarks
from imutils import face_utils
import argparse
import imutils
import dlib

# %% [markdown]
# Input dataset location

# %%
dataset_path = '/content/drive/MyDrive/Msthesis/Dataset/images3'
print(dataset_path)
# Out:
# /content/drive/MyDrive/Msthesis/Dataset/images3

# %% [markdown]
# define locations to store landmarks file

# %%
processed_data_path = dataset_path+"/../processed_data3"
print(processed_data_path)


if not os.path.exists(processed_data_path):
    os.mkdir(processed_data_path)



landmark_path = processed_data_path + "/landmarks/"
if not os.path.exists(landmark_path):
    os.mkdir(landmark_path)

annotated_image_path =  processed_data_path + "/annotated_images/"
if not os.path.exists(annotated_image_path):
    os.mkdir(annotated_image_path)


print("landmark_path:", landmark_path)
print("annotated_image_path:", annotated_image_path)
# Out:
# /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3
# landmark_path: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/
# annotated_image_path: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/annotated_images/

# %% [markdown]
# Initializing the detector and predictor for landmark detection

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("./drive/MyDrive/Msthesis/code/shape_predictor_68_face_landmarks.dat")

# %% [markdown]
# Data loader Class

# %%
class data_loader():
    def load_data(self, path, category='smile'):
        #for each subfolder(labels) in the path
        for label in os.listdir(path):
            #for each image in the subfolder
            if not os.path.exists(landmark_path + label):
              os.mkdir(landmark_path + label)

            if not os.path.exists(annotated_image_path + label):
              os.mkdir(annotated_image_path + label)

            for image_name in os.listdir(path + label+"/"+category):

                print("the path created:", landmark_path + label+"/"+category)
                if not os.path.exists(landmark_path + label+"/"+category):
                    os.mkdir(landmark_path + label+"/"+category)
                if not os.path.exists(annotated_image_path + label+"/"+category):
                    os.mkdir(annotated_image_path + label+"/"+category)


                #load the image
                image = cv2.imread(path + label + "/"+category+"/" + image_name)

                #get 2D landmarks from the image with the annoted image
                landmarks,image = self.get_2D_landmarks(image)

                #save the landmarks in a file
                file_landmarks = open(landmark_path + label + "/" + category + "/" + image_name[:-4] + ".txt", "w")
                for landmark in landmarks:
                    file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

                #save the annotated image
                cv2.imwrite(annotated_image_path + label + "/"+ category + "/" + image_name, image)

            print("label:", label)





    def get_2D_landmarks(self, image):
        #get 2D landmarks from the image

        #resize image to a fixed-size
        image =imutils.resize(image, width=500)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        rects = detector(gray, 1)

        landmarks = []
        for (i, rect) in enumerate(rects):
            # determine the facial landmarks for the face region, then
            # convert the facial landmark (x, y)-coordinates to a NumPy
            # array
            shape = predictor(gray, rect)
            shape = face_utils.shape_to_np(shape)
            # convert dlib's rectangle to a OpenCV-style bounding box
            # [i.e., (x, y, w, h)], then draw the face bounding box
            (x, y, w, h) = face_utils.rect_to_bb(rect)
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
            # show the face number
            cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            # loop over the (x, y)-coordinates for the facial landmarks
            # and draw them on the image
            for (x, y) in shape:
                cv2.circle(image, (x, y), 1, (0, 0, 255), -1)
                landmarks.append((x, y))

            #annotate the image with the landmarks

        return landmarks,image

# %%
dl = data_loader()
print('Loading neutral images...')
dl.load_data(dataset_path+"/", category='neutral')
print('Neutral images loading done!\nLoading smile images...')
dl.load_data(dataset_path+"/", category='smile')
print('Smile images loading done!')
# Out:
# Loading neutral images...
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/001/neutral
# label: 001
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/013/neutral
# label: 013
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/003/neutral
# label: 003
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/002/neutral
# label: 002
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/005/neutral
# label: 005
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/010/neutral
# label: 010
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/014/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/014/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/014/neutral
# label: 014
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/004/neutral
# label: 004
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/011/neutral
# label: 011
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/012/neutral
# label: 012
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/019/neutral
# label: 019
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/020/neutral
# label: 020
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/052/neutral
# label: 052
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/051/neutral
# label: 051
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/015/neutral
# label: 015
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/021/neutral
# label: 021
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/016/neutral
# label: 016
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/023/neutral
# label: 023
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/018/neutral
# label: 018
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/017/neutral
# label: 017
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/054/neutral
# label: 054
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/066/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/066/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/066/neutral
# label: 066
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/057/neutral
# label: 057
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/061/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/061/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/061/neutral
# label: 061
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/058/neutral
# label: 058
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/059/neutral
# label: 059
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/056/neutral
# label: 056
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/067/neutral
# label: 067
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/063/neutral
# label: 063
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/060/neutral
# label: 060
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/084/neutral
# label: 084
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/073/neutral
# label: 073
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/088/neutral
# label: 088
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/089/neutral
# label: 089
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/078/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/078/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/078/neutral
# label: 078
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/074/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/074/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/074/neutral
# label: 074
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/080/neutral
# label: 080
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/071/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/071/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/071/neutral
# label: 071
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/072/neutral
# label: 072
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/069/neutral
# label: 069
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/096/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/096/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/096/neutral
# label: 096
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/093/neutral
# label: 093
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/097/neutral
# label: 097
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/100/neutral
# label: 100
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/092/neutral
# label: 092
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/099/neutral
# label: 099
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/095/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/095/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/095/neutral
# label: 095
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/098/neutral
# label: 098
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/091/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/091/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/091/neutral
# label: 091
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/101/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/101/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/101/neutral
# label: 101
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/106/neutral
# label: 106
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/108/neutral
# label: 108
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/107/neutral
# label: 107
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/113/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/113/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/113/neutral
# label: 113
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/110/neutral
# label: 110
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/102/neutral
# label: 102
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/104/neutral
# label: 104
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/105/neutral
# label: 105
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/114/neutral
# label: 114
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/103/neutral
# label: 103
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/120/neutral
# label: 120
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/127/neutral
# label: 127
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/123/neutral
# label: 123
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/121/neutral
# label: 121
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/119/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/119/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/119/neutral
# label: 119
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/126/neutral
# label: 126
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/116/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/116/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/116/neutral
# label: 116
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/115/neutral
# label: 115
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/117/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/117/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/117/neutral
# label: 117
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/122/neutral
# label: 122
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/134/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/134/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/134/neutral
# label: 134
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/131/neutral
# label: 131
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/130/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/130/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/130/neutral
# label: 130
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/129/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/129/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/129/neutral
# label: 129
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/139/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/139/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/139/neutral
# label: 139
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/133/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/133/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/133/neutral
# label: 133
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/136/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/136/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/136/neutral
# label: 136
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/140/neutral
# label: 140
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/137/neutral
# label: 137
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/132/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/132/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/132/neutral
# label: 132
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/148/neutral
# label: 148
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/154/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/154/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/154/neutral
# label: 154
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/157/neutral
# label: 157
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/158/neutral
# label: 158
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/155/neutral
# ...
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/527/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/527/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/527/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/527/smile
# label: 527
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/532/smile
# label: 532
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/529/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/529/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/529/smile
# label: 529
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/528/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/528/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/528/smile
# label: 528
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/526/smile
# label: 526
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/539/smile
# label: 539
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/537/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/537/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/537/smile
# label: 537
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/540/smile
# label: 540
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/547/smile
# label: 547
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/538/smile
# label: 538
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/553/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/553/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/553/smile
# label: 553
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/542/smile
# label: 542
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/541/smile
# label: 541
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/546/smile
# label: 546
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/550/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/550/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/550/smile
# label: 550
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/563/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/563/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/563/smile
# label: 563
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/554/smile
# label: 554
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/558/smile
# label: 558
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/555/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/555/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/555/smile
# label: 555
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/561/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/561/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/561/smile
# label: 561
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/562/smile
# label: 562
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/557/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/557/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/557/smile
# label: 557
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/556/smile
# label: 556
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/560/smile
# label: 560
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/559/smile
# label: 559
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/564/smile
# label: 564
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/464/smile
# label: 464
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/265/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/265/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/265/smile
# label: 265
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/260/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/260/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/260/smile
# label: 260
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/255/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/255/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/255/smile
# label: 255
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/172/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/172/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/172/smile
# label: 172
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/491/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/491/smile
# the path created: /content/drive/MyDrive/Msthesis/Dataset/images3/../processed_data3/landmarks/491/smile
# label: 491
# Smile images loading done!

# %% [markdown]
# Feature Extractor

# %% [markdown]
# Mouth_features

# %%
import numpy as np

class Features_Mouth:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            eyes_angle_features = [0,0,0,0]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]
            nose_angle_features = [0,0,0,0]

            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Nose_features

# %%
import numpy as np

class Features_Nose:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            mouth_angle_features = [0,0,0,0]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            eyes_angle_features = [0,0,0,0]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]


            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Eye_Features

# %%
import numpy as np

class Features_Eye:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            mouth_angle_features = [0,0,0,0]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]
            nose_angle_features = [0,0,0,0]


            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Mouth-Eye features

# %%
import numpy as np

class Features_mouth_eye:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]
            nose_angle_features = [0,0,0,0]


            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Eye-Nose Features

# %%
import numpy as np

class Features_eye_nose:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            mouth_angle_features = [0,0,0,0]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]



            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Mouth-Nose Features

# %%
import numpy as np

class Features_mouth_nose:

    def normalize_array(self, arr):
        if len(arr) == 0:
            return arr
        arr = np.array(arr)
        max = arr.max()
        if max == 0:
            return arr
        arr = arr / max
        return arr.tolist()

    def get_features_from_path(self, image_path, includes='dabenm'):

        # landmark_file_path = landmark_path + label + "/" + cat + "/" +landmark_file_name
        image = cv2.imread(image_path)


        dl = data_loader()
        ldm, _ = dl.get_2D_landmarks(image)

        print("length:", len(ldm))

         #save the landmarks in a file
        file_landmarks = open("temp.txt", "w")
        for landmark in ldm:
            file_landmarks.write(str(landmark[0]) + " " + str(landmark[1]) + "\n")

        file_landmarks.close()

        file_landmarks = open("temp.txt", "r")
        lines = file_landmarks.readlines()

        print("lines:", lines)

        features = self.get_features(lines, includes)

        print("features: ", features)

        return features


    def get_features(self, lines, includes="dabenm"):
        self.includes = includes
        # function to get the distance features from the landmarks
        #convert the lines to a list of tuples
        lines = [tuple(map(int, line.split())) for line in lines]


        def distance(a,b):
            return ((a[0]-b[0])**2 + (a[1]-b[1])**2)**0.5

        def get_distance_features(lines):

            def slope(a,b):
                return ((b[1]-a[1])/(b[0]-a[0]))

            # pairs from landmark_based_fr.pdf

            basic_shape_pairs = [
                [lines[1], lines[15]],
                [lines[27], lines[57]],
                [lines[36], lines[48]],
                [lines[45], lines[54]],
                [lines[36], lines[45]],
                [lines[17], lines[21]],
                [lines[22], lines[26]],
            ]

            eyes_pairs = [
                [lines[36], lines[39]],
                [lines[42], lines[45]],
                [lines[38], lines[40]],
                [lines[43], lines[47]],
            ]

            nose_pairs = [
                [lines[31], lines[35]],
                [lines[27], lines[30]],
                [lines[30], lines[31]],
                [lines[30], lines[35]],
                [lines[28], lines[31]],
                [lines[28], lines[35]],
            ]

            mouth_pairs = [
                [lines[48], lines[54]],
                [lines[60], lines[64]],
                [lines[49], lines[53]],
                [lines[59], lines[55]],
            ]

            basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
            nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
            mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
            eyes_dists = [distance(pair[0], pair[1]) for pair in eyes_pairs]



            features = []
            if "b" in self.includes:
                features = features + basic_shape_dists
            if "m" in self.includes:
                features = features + mouth_dists
            if "n" in self.includes:
                features = features + nose_dists
            if "e" in self.includes:
                features = features + eyes_dists

            if 'd' in self.includes:
                features = features
            else:
                features = basic_shape_dists

            features = self.normalize_array(features)

            return features

        # function to get the angle features from the landmarks
        def get_angle_features(self, lines):
            def angle(a,b,c):
                a = np.asarray(a)
                b = np.asarray(b)
                c = np.asarray(c)
                ba = a - b
                bc = c - b

                cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
                if cosine_angle < -1 or cosine_angle > 1:
                    cosine_angle = 0.8
                angle = np.arccos(cosine_angle)

                return angle

            # triplets to find the angle.
            mouth_triplets = [
                [lines[50], lines[48], lines[61]],
                [lines[67], lines[48], lines[58]],
                [lines[52], lines[54], lines[63]],
                [lines[65], lines[54], lines[56]],
            ]

            eyes_triplets = [
                [lines[37], lines[36], lines[41]],
                [lines[38], lines[39], lines[40]],
                [lines[43], lines[42], lines[47]],
                [lines[44], lines[45], lines[46]],
            ]

            nose_triplets = [
                [lines[27], lines[31], lines[35]],
                [lines[30], lines[31], lines[35]],
                [lines[27], lines[35], lines[31]],
                [lines[30], lines[35], lines[31]],
            ]

            # angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in point_triplets]

            mouth_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in mouth_triplets]
            eyes_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in eyes_triplets]
            eye_angle_features = [0,0,0,0]
            nose_angle_features = [angle(triplet[0], triplet[1], triplet[2]) for triplet in nose_triplets]



            angle_features = []

            if "m" in self.includes:
                angle_features = angle_features + mouth_angle_features
            if "n" in self.includes:
                angle_features = angle_features + nose_angle_features
            if "e" in self.includes:
                angle_features = angle_features + eyes_angle_features


            angle_features = self.normalize_array(angle_features)

            return angle_features

        # get distance features
        dist_features = get_distance_features(lines)

        # get angle features
        angle_features = get_angle_features(self, lines)

        # combine the features
        # features = dist_features + angle_features
        # features = dist_features
        # print("features:", features)

        features = dist_features

        # if 'd' in self.includes:
        #     features = features + dist_features
        if 'a' in self.includes:
            features = features + angle_features

        return features

# %% [markdown]
# Model

# %%
import os
import random
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Predictor class

# %% [markdown]
# Model_Mouth

# %%
class Model_mouth():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_Mouth()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Model_Nose

# %%
class Model_Nose():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_Nose()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Model_Eye

# %%
class Model_eye():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_Eye()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Model Mouth-Eye

# %%
class Model_mouth_eye():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_mouth_eye()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Model Eye-Nose

# %%
class Model_eye_nose():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_eye_nose()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Model Mouth-Nose

# %%
class Model_mouth_nose():
    def __init__(self, test_size=0.2, low_number_of_images=2, high_number_of_images=1000, kernel_type="poly", proba = True, scale_feature = False, method = "svm", category=None):
        self.test_size = test_size
        self.low_number_of_images = low_number_of_images
        self.high_number_of_images = high_number_of_images
        self.kernel_type = kernel_type
        self.proba = proba

        self.feature_extractor = Features_mouth_nose()
        self.scale_feature = scale_feature
        self.method = method

        self.scaler = StandardScaler()


    def generate_train_test_split(self, category='neutral', includes='dabenm'):
        # print(landmark_path)

        #define features and labels
        train_features = []
        train_labels = []

        test_features = []
        test_labels = []
        #for each subfolder(labels) in the path
        cnt_valid_labels = 0
        for label in os.listdir(landmark_path):
            #get the number of images with only 1 person in the image
            cnt =len(os.listdir(landmark_path + label+ "/" +category))
            # for file_name in os.listdir(landmark_path + label+ "/" +category):
            #     file = open(landmark_path + label + "/" + category+"/"+ file_name, "r")
            #     lines = file.readlines()
            #     if len(lines) == 68:
            #         cnt += 1
            #     file.close()

            #if the number of images is between the low and high number of images
            if cnt >= self.low_number_of_images and cnt <= self.high_number_of_images:
                # print('here')
                cnt_valid_labels += 1

                #for each landmark file in the subfolder
                for file_name in os.listdir(landmark_path + label+ "/" +category):
                    # print(file_name)
                    file = open(landmark_path + label + "/" + category + "/" + file_name, "r")
                    lines = file.readlines()
                    if len(lines) == 68:
                        #get the features and labels for the image
                        # features = self.get_features(landmark_path + label + "/" + file_name)
                        features = self.feature_extractor.get_features(lines, includes)

                        #check if the image is in the test set or the train set
                        if random.random() < self.test_size:
                            test_features.append(features)
                            test_labels.append(label)
                        else:
                            train_features.append(features)
                            train_labels.append(label)

            #convert the features and labels to numpy arrays
            self.x_train = np.array(train_features, dtype=np.float64)
            self.x_test = np.array(test_features, dtype=np.float64)
            self.y_train = np.array(train_labels, dtype=object)
            self.y_test = np.array(test_labels, dtype=object)


        # print("Valid labels:", cnt_valid_labels)




    def train_model(self, category=None):

        if self.scale_feature:
          self.x_train = self.scaler.fit_transform(self.x_train)
          self.x_test = self.scaler.transform(self.x_test)

        if self.method == "svm":
          #train the SVM
          self.model = svm.SVC(kernel=self.kernel_type, probability=self.proba)
          self.model.fit(self.x_train, self.y_train)

        elif self.method == "rand_forest":
          #self.model= RandomForestClassifier(n_estimators = 200, criterion = 'entropy', random_state = 42)
          #cv = KFold(n_splits=10, random_state=1, shuffle=True)
          #self.model.fit(self.x_train, self.y_train)
          #cross_val_score(model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1)
          self.model = RandomForestClassifier()
          cv = KFold(n_splits=10, random_state=1, shuffle=True)
          self.model.fit(self.x_train, self.y_train)
          print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))

        #save the model
        if category is None:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model.pkl")
        else:
          joblib.dump(self.model, "/content/drive/MyDrive/Msthesis/model/svm_model_only_spon_" + category + ".pkl")

        # print("SVM model saved")

    def get_accuracy2(self, x_test=None, y_test=None):
        #get the accuracy of the model
        cm = None

        def second_max(lst):
            m1, m2 = max(lst), float('-inf')
            for x in lst:
                if x != m1:
                    m2 = max(m2, x)
            return m2

        if x_test is None or y_test is None:
          self.y_pred = self.model.predict(self.x_test);
          # cm = confusion matrix
          cm = confusion_matrix(self.y_test, self.y_pred, normalize='true')
        else:
          y_pred = self.model.predict(x_test)
          cm = confusion_matrix(y_test, y_pred, normalize='true')

        if cm is None:
            return 0.0, 0.0, 0.0

        accuracy_rate = sum(cm.diagonal()) / len(cm)
        not_sure_rate = sum(1 for row in cm if max(row) - second_max(row) < 0.1) / len(cm)
        inaccuracy_rate = 1 - accuracy_rate - not_sure_rate

        return accuracy_rate, not_sure_rate, inaccuracy_rate


    def get_accuracy(self, x_test=None, y_test=None):
        #get the accuracy of the model
        # predict probabilities of each instance

        if x_test is None or y_test is None:
            x_test = self.x_test
            y_test = self.y_test


        probabilities = self.model.predict_proba(x_test)

        undetermined = 0
        accurate = 0
        inaccurate = 0

        # loop through each instance and determine the prediction accuracy
        for i in range(len(x_test)):
            pred_class_idx = np.argmax(probabilities[i])
            pred_class = self.model.classes_[pred_class_idx]
            pred_prob = probabilities[i][pred_class_idx]
            second_highest_prob = sorted(probabilities[i])[-2]

            if (pred_prob - second_highest_prob) > 0.02:
                # print('a', pred_class, y_test[i])
                if pred_class == y_test[i]:
                    accurate += 1
                else:
                    inaccurate += 1
            else:
                undetermined += 1

        accuracy_rate = accurate / len(x_test)
        uncertainty = undetermined / len(x_test)
        inaccuracy_rate = inaccurate / len(x_test)

        return accuracy_rate, uncertainty, inaccuracy_rate

    def predict(self, image_path, includes='dabenm'):
        #predict the label of the image
        features = self.feature_extractor.get_features_from_path(image_path, includes)
        #convert the features to a numpy array
        features = np.array(features, dtype=np.float64)

        #reshape the features
        features = features.reshape((1, features.shape[0]))

        if self.scale_feature:
          features = self.scaler.transform(features)
        #predict the label with confidence
        prediction = self.model.predict(features)
        confidence = self.model.predict_proba(features)

        print(prediction)
        return prediction[0],confidence


    def get_testset(self):
        return self.x_test, self.y_test

# %% [markdown]
# Test with each combination

# %%
includes = 'dabenm'

# %%
# Mouth features Model
sv_m = Model_mouth(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_m.generate_train_test_split(category='neutral', includes=includes)
sv_m.train_model(category='neutral')
# Out:
# [0.71929825 0.65789474 0.71052632 0.71929825 0.69298246 0.69298246
#  0.76315789 0.69298246 0.73684211 0.77192982]

# %%
# Nose features Model
sv_n = Model_Nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_n.generate_train_test_split(category='neutral', includes=includes)
sv_n.train_model(category='neutral')
# Out:
# [0.66949153 0.71186441 0.68644068 0.7008547  0.73504274 0.72649573
#  0.73504274 0.66666667 0.76068376 0.73504274]

# %%
# Eye features Model
sv_e = Model_eye(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_e.generate_train_test_split(category='neutral', includes=includes)
sv_e.train_model(category='neutral')
# Out:
# [0.69230769 0.71794872 0.75       0.64655172 0.72413793 0.80172414
#  0.6637931  0.73275862 0.71551724 0.71551724]

# %%
# Mouth_eye features Model
sv_me = Model_mouth_eye(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_me.generate_train_test_split(category='neutral', includes=includes)
sv_me.train_model(category='neutral')
# Out:
# [0.74336283 0.73451327 0.67256637 0.68141593 0.78761062 0.74336283
#  0.68141593 0.77678571 0.66964286 0.66964286]

# %%
# Eye-Nose features Model
sv_en = Model_eye_nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_en.generate_train_test_split(category='neutral', includes=includes)
sv_en.train_model(category='neutral')
# Out:
# [0.72807018 0.77192982 0.68421053 0.66371681 0.7079646  0.62831858
#  0.73451327 0.77876106 0.73451327 0.6460177 ]

# %%
# Mouth-Nose features Model
sv_mn = Model_mouth_nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
sv_mn.generate_train_test_split(category='neutral', includes=includes)
sv_mn.train_model(category='neutral')
# Out:
# [0.64655172 0.70689655 0.64655172 0.71304348 0.73913043 0.70434783
#  0.72173913 0.77391304 0.7826087  0.69565217]

# %%
print('neutral - neutral')
# neutral Face-neutral Mouth
accuracy_rate, not_sure_rate, inaccuracy_rate = sv_m.get_accuracy()
print('neutral Face-neutral Mouth')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))

# neutral Face-neutral Nose

accuracy_rate, not_sure_rate, inaccuracy_rate = sv_n.get_accuracy()
print('neutral Face-neutral Nose')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))

# neutral Face-neutral Eye
accuracy_rate, not_sure_rate, inaccuracy_rate = sv_e.get_accuracy()
print('neutral Face-neutral Eye')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))

# neutral Face-neutral Mouth_Eye

accuracy_rate, not_sure_rate, inaccuracy_rate = sv_me.get_accuracy()
print('neutral Face-neutral Mouth_Eye')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))

# neutral Face-neutral Eye_Nose

accuracy_rate, not_sure_rate, inaccuracy_rate = sv_en.get_accuracy()
print('neutral Face-neutral Eye_Nose')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))

# neutral Face-neutral Mouth_Nose

accuracy_rate, not_sure_rate, inaccuracy_rate = sv_mn.get_accuracy()
print('neutral Face-neutral Mouth_Nose')
print("\taccuracy_rate: {:.2f}%".format(accuracy_rate * 100))
print("\tnot_sure_rate: {:.2f}%".format(not_sure_rate * 100))
print("\tinaccuracy_rate: {:.2f}%".format(inaccuracy_rate * 100))
# Out:
# neutral - neutral
# neutral Face-neutral Mouth
# 	accuracy_rate: 68.01%
# 	not_sure_rate: 16.16%
# 	inaccuracy_rate: 15.82%
# neutral Face-neutral Nose
# 	accuracy_rate: 73.11%
# 	not_sure_rate: 12.12%
# 	inaccuracy_rate: 14.77%
# neutral Face-neutral Eye
# 	accuracy_rate: 64.36%
# 	not_sure_rate: 18.91%
# 	inaccuracy_rate: 16.73%
# neutral Face-neutral Mouth_Eye
# 	accuracy_rate: 69.68%
# 	not_sure_rate: 15.48%
# 	inaccuracy_rate: 14.84%
# neutral Face-neutral Eye_Nose
# 	accuracy_rate: 67.11%
# 	not_sure_rate: 18.42%
# 	inaccuracy_rate: 14.47%
# neutral Face-neutral Mouth_Nose
# 	accuracy_rate: 71.13%
# 	not_sure_rate: 17.25%
# 	inaccuracy_rate: 11.62%

# %% [markdown]
# Test Multiple times and take average

# %%
includes = 'ns'
MAX_ITER = 1
METHOD = 'svm'

# %%
# Mouth Model
def get_mouth_model(includes='ns'):
    sv_m = Model_mouth(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_m.generate_train_test_split(category='neutral', includes=includes)
    sv_m.train_model(category='neutral')
    return sv_m

# %%
# Nose Model
def get_nose_model(includes='ns'):
    sv_n = Model_Nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_n.generate_train_test_split(category='neutral', includes=includes)
    sv_n.train_model(category='neutral')
    return sv_n

# %%
# Eye Model
def get_eye_model(includes='ns'):
    sv_e = Model_eye(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_e.generate_train_test_split(category='neutral', includes=includes)
    sv_e.train_model(category='neutral')
    return sv_e

# %%
# Mouth-Eye Model
def get_mouth_eye_model(includes='ns'):
    sv_me = Model_mouth_eye(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_me.generate_train_test_split(category='neutral', includes=includes)
    sv_me.train_model(category='neutral')
    return sv_e

# %%
# # Eye-Nose features Model
def get_eye_nose_model(includes='ns'):
    sv_en = Model_eye_nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_en.generate_train_test_split(category='neutral', includes=includes)
    sv_en.train_model(category='neutral')
    return sv_en

# %%
#  # Mouth-Nose features Model
def get_mouth_nose_model(includes='ns'):
    sv_mn = Model_mouth_nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
    sv_mn.generate_train_test_split(category='neutral', includes=includes)
    sv_mn.train_model(category='neutral')
    return sv_mn

# %%
rates = np.zeros(20)
print('\r' + '-'*int(MAX_ITER*100/MAX_ITER), end=f' {0}%')
for i in range(MAX_ITER):
    # print(i, end=' ')
    mouth_model = get_mouth_model(includes=includes)
    nose_model = get_nose_model(includes=includes)
    eye_model = get_eye_model(includes=includes)
    mouth_eye_model = get_mouth_eye_model(includes=includes)
    eye_nose_model = get_eye_nose_model(includes=includes)
    mouth_nose_model = get_mouth_nose_model(includes=includes)

    print('\r' + '*'*int((i+0.5)*100/MAX_ITER) + '-'*int((MAX_ITER-i-0.5)*100/MAX_ITER), end=f' {(i+0.5)/MAX_ITER * 100}%')
    # neutral-Mouth
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_m.get_accuracy()
    rates[0] += accuracy_rate
    rates[1] += not_sure_rate
    rates[2] += inaccuracy_rate

    # neutral-Nose
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_n.get_accuracy()
    rates[3] += accuracy_rate
    rates[4] += not_sure_rate
    rates[5] += inaccuracy_rate

    # neutral-Eye
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_e.get_accuracy()
    rates[6] += accuracy_rate
    rates[7] += not_sure_rate
    rates[8] += inaccuracy_rate

    # neutral-Mouth_Eye
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_me.get_accuracy()
    rates[9] += accuracy_rate
    rates[10] += not_sure_rate
    rates[11] += inaccuracy_rate

    # neutral-Eye_Nose
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_en.get_accuracy()
    rates[12] += accuracy_rate
    rates[13] += not_sure_rate
    rates[14] += inaccuracy_rate

    # neutral-Mouth_Nose
    accuracy_rate, not_sure_rate, inaccuracy_rate = sv_mn.get_accuracy()
    rates[15] += accuracy_rate
    rates[16] += not_sure_rate
    rates[17] += inaccuracy_rate


    print('\r' + '*'*int((i+1)*100/MAX_ITER) + '-'*int((MAX_ITER-i-1)*100/MAX_ITER), end=f' {(i+1)/MAX_ITER * 100}%')

rates = rates / MAX_ITER
# Out:
# ---------------------------------------------------------------------------------------------------- 0%[0.37931034 0.48275862 0.4137931  0.46551724 0.45689655 0.40517241
#  0.44827586 0.49565217 0.54782609 0.49565217]
# [0.4173913  0.4173913  0.3826087  0.46956522 0.40350877 0.54385965
#  0.44736842 0.37719298 0.47368421 0.56140351]
# [0.48275862 0.43103448 0.4        0.43478261 0.45217391 0.47826087
#  0.53043478 0.52173913 0.46956522 0.44347826]
# [0.45217391 0.5        0.45614035 0.45614035 0.45614035 0.44736842
#  0.46491228 0.4122807  0.49122807 0.45614035]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-ed29f1ddf772> in <cell line: 3>()
#       7     eye_model = get_eye_model(includes=includes)
#       8     mouth_eye_model = get_mouth_eye_model(includes=includes)
# ----> 9     eye_nose_model = get_eye_nose_model(includes=includes)
#      10     mouth_nose_model = get_mouth_nose_model(includes=includes)
#      11
#
# <ipython-input-72-0ccafe29ca14> in get_eye_nose_model(includes)
#       3     sv_en = Model_eye_nose(test_size=0.2, low_number_of_images=4, kernel_type = "poly", scale_feature= True, method="rand_forest", category='neutral')
#       4     sv_en.generate_train_test_split(category='neutral', includes=includes)
# ----> 5     sv_en.train_model(category='neutral')
#       6     return sv_en
#
# <ipython-input-56-51aa6d8d4735> in train_model(self, category)
#      88           self.model = RandomForestClassifier()
#      89           cv = KFold(n_splits=10, random_state=1, shuffle=True)
# ---> 90           self.model.fit(self.x_train, self.y_train)
#      91           print(cross_val_score(self.model, self.x_train, self.y_train, scoring='accuracy', cv=cv, n_jobs=-1))
#      92
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     471             # parallel_backend contexts set at a higher level,
#     472             # since correctness does not rely on using threads.
# --> 473             trees = Parallel(
#     474                 n_jobs=self.n_jobs,
#     475                 verbose=self.verbose,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1861             output = self._get_sequential_output(iterable)
#    1862             next(output)
# -> 1863             return output if self.return_generator else list(output)
#    1864
#    1865         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1790                 self.n_dispatched_batches += 1
#    1791                 self.n_dispatched_tasks += 1
# -> 1792                 res = func(*args, **kwargs)
#    1793                 self.n_completed_tasks += 1
#    1794                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     183
# --> 184         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185     else:
#     186         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     887         """
#     888
# --> 889         super().fit(
#     890             X,
#     891             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     377             )
#     378
# --> 379         builder.build(self.tree_, X, y, sample_weight)
#     380
#     381         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
# Smile-Mouth
print('Smile-Mouth')
print("\taccuracy_rate: {:.2f}%".format(rates[0] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[1] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[2] * 100))

# Smile-Nose
print('Smile-Nose')
print("\taccuracy_rate: {:.2f}%".format(rates[3] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[4] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[5] * 100))

# Smile-Eye
print('Smile-Eye')
print("\taccuracy_rate: {:.2f}%".format(rates[6] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[7] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[8] * 100))

# Smile-Mouth_Eye
print('Smile-Mouth_Eye')
print("\taccuracy_rate: {:.2f}%".format(rates[9] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[10] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[11] * 100))

# Smile-Eye_Nose
print('Smile-Eye_Nose')
print("\taccuracy_rate: {:.2f}%".format(rates[12] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[13] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[14] * 100))

# Smile-Mouth_Nose
print('Smile-Mouth_Nose')
print("\taccuracy_rate: {:.2f}%".format(rates[15] * 100))
print("\tuncertainty_rate: {:.2f}%".format(rates[16] * 100))
print("\tinaccuracy_rate: {:.2f}%".format(rates[17] * 100))
# Out:
# Smile-Mouth
# 	accuracy_rate: 70.81%
# 	uncertainty_rate: 15.10%
# 	inaccuracy_rate: 14.09%
# Smile-Nose
# 	accuracy_rate: 72.89%
# 	uncertainty_rate: 13.38%
# 	inaccuracy_rate: 13.73%
# Smile-Eye
# 	accuracy_rate: 68.60%
# 	uncertainty_rate: 17.06%
# 	inaccuracy_rate: 14.33%
# Smile-Mouth_Eye
# 	accuracy_rate: 66.79%
# 	uncertainty_rate: 17.71%
# 	inaccuracy_rate: 15.50%
# Smile-Eye_Nose
# 	accuracy_rate: 68.38%
# 	uncertainty_rate: 17.53%
# 	inaccuracy_rate: 14.09%
# Smile-Mouth_Nose
# 	accuracy_rate: 71.03%
# 	uncertainty_rate: 13.45%
# 	inaccuracy_rate: 15.52%

# %% [markdown]
# All at once

# %%
# Mouth Model
def get_mouth_model(includes='ns', method='svm'):
    sv_m = Model_mouth(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_m.generate_train_test_split(category='smile', includes=includes)
    sv_m.train_model(category='smile')
    return sv_m

# Nose Model
def get_nose_model(includes='ns', method='svm'):
    sv_n = Model_Nose(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_n.generate_train_test_split(category='smile', includes=includes)
    sv_n.train_model(category='smile')
    return sv_n

# Eye Model
def get_eye_model(includes='ns', method='svm'):
    sv_e = Model_eye(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_e.generate_train_test_split(category='smile', includes=includes)
    sv_e.train_model(category='smile')
    return sv_e

# Mouth_Eye Model
def get_mouth_eye_model(includes='ns', method='svm'):
    sv_me = Model_mouth_eye(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_me.generate_train_test_split(category='smile', includes=includes)
    sv_me.train_model(category='smile')
    return sv_me

# Eye_Nose Model
def get_eye_nose_model(includes='ns', method='svm'):
    sv_en = Model_eye_nose(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_en.generate_train_test_split(category='smile', includes=includes)
    sv_en.train_model(category='smile')
    return sv_en

# Mouth_Nose Model
def get_mouth_nose_model(includes='ns', method='svm'):
    sv_mn = Model_mouth_nose(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
    sv_mn.generate_train_test_split(category='smile', includes=includes)
    sv_mn.train_model(category='smile')
    return sv_mn



def task(includes='ns', method='svm', max_iter=20):
    rates = np.zeros(20)
    MAX_ITER = max_iter
    print('\r' + '-'*int(MAX_ITER*100/MAX_ITER), end=f' {0}%')
    for i in range(MAX_ITER):
        # print(i, end=' ')
        mouth_model = get_mouth_model(includes=includes, method=method)
        nose_model = get_nose_model(includes=includes, method=method)
        eye_model = get_eye_model(includes=includes, method=method)
        mouth_eye_model = get_mouth_eye_model(includes=includes, method=method)
        eye_nose_model = get_eye_nose_model(includes=includes, method=method)
        mouth_nose_model = get_mouth_nose_model(includes=includes, method=method)

        print('\r' + '*'*int((i+0.5)*100/MAX_ITER) + '-'*int((MAX_ITER-i-0.5)*100/MAX_ITER), end=f' {(i+0.5)/MAX_ITER * 100}%')


        # Smile_Mouth
        accuracy_rate, not_sure_rate, inaccuracy_rate = mouth_model.get_accuracy()
        rates[0] += accuracy_rate
        rates[1] += not_sure_rate
        rates[2] += inaccuracy_rate

        # Smile-Nose
        accuracy_rate, not_sure_rate, inaccuracy_rate = nose_model.get_accuracy()
        rates[3] += accuracy_rate
        rates[4] += not_sure_rate
        rates[5] += inaccuracy_rate

        # Smile-Eye
        accuracy_rate, not_sure_rate, inaccuracy_rate = eye_model.get_accuracy()
        rates[6] += accuracy_rate
        rates[7] += not_sure_rate
        rates[8] += inaccuracy_rate

        # Smile-Mouth_Eye
        accuracy_rate, not_sure_rate, inaccuracy_rate = mouth_eye_model.get_accuracy()
        rates[9] += accuracy_rate
        rates[10] += not_sure_rate
        rates[11] += inaccuracy_rate

        # Smile-Eye_Nose
        accuracy_rate, not_sure_rate, inaccuracy_rate = eye_nose_model.get_accuracy()
        rates[12] += accuracy_rate
        rates[13] += not_sure_rate
        rates[14] += inaccuracy_rate

        # Smile-Mouth_Nose
        accuracy_rate, not_sure_rate, inaccuracy_rate = mouth_nose_model.get_accuracy()
        rates[15] += accuracy_rate
        rates[16] += not_sure_rate
        rates[17] += inaccuracy_rate

        print('\r' + '*'*int((i+1)*100/MAX_ITER) + '-'*int((MAX_ITER-i-1)*100/MAX_ITER), end=f' {(i+1)/MAX_ITER * 100}%')

    rates = rates / MAX_ITER


    # Smile-Mouth
    print('Smile-Mouth')
    print("\taccuracy_rate: {:.2f}%".format(rates[0] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[1] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[2] * 100))

    # Smile-Nose
    print('Smile-Nose')
    print("\taccuracy_rate: {:.2f}%".format(rates[3] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[4] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[5] * 100))

    # Smile-Eye
    print('Smile-Eye')
    print("\taccuracy_rate: {:.2f}%".format(rates[6] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[7] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[8] * 100))

    # Smile-Mouth_Eye
    print('Smile-Mouth_Eye')
    print("\taccuracy_rate: {:.2f}%".format(rates[9] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[10] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[11] * 100))

    # Smile-Eye_Nose
    print('Smile-Eye_Nose')
    print("\taccuracy_rate: {:.2f}%".format(rates[12] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[13] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[14] * 100))

    # Smile-Mouth_Nose
    print('Smile-Mouth_Nose')
    print("\taccuracy_rate: {:.2f}%".format(rates[15] * 100))
    print("\tuncertainty_rate: {:.2f}%".format(rates[16] * 100))
    print("\tinaccuracy_rate: {:.2f}%".format(rates[17] * 100))

    return mouth_model, nose_model, eye_model, mouth_eye_model, eye_nose_model, mouth_nose_model

# %%
n_iter = 10 #10
iterations = [
    ['ns', 'svm', n_iter],
    # ['n', 'svm', n_iter],
    ['ns', 'rand_forest', n_iter],
    # ['n', 'rand_forest', n_iter],
    # ['ns', 'decision_tree', n_iter],
    # ['n', 'decision_tree', n_iter],
    # ['ns', 'knn', n_iter],
    # ['n', 'knn', n_iter],
    ['ns', 'lda', n_iter],
    # ['n', 'lda', n_iter],
    ['ns', 'lr', n_iter],
    # ['n', 'lr', n_iter],
    # ['ns', 'naive_bayes', n_iter],
    # ['n', 'naive_bayes', n_iter],
    # ['ns', 'gbm', 1],  # very slow
    # ['n', 'gbm', 1],   # very slow
]

for iter in iterations:
    task(iter[0], iter[1], iter[2])
# Out:
# ---------------------------------------------------------------------------------------------------- 0%[0.45299145 0.37068966 0.54310345 0.37068966 0.42241379 0.44827586
#  0.45689655 0.39655172 0.51724138 0.51724138]
# [0.51724138 0.46551724 0.4137931  0.43965517 0.44827586 0.43478261
#  0.4        0.47826087 0.45217391 0.48695652]
# [0.43965517 0.46551724 0.38793103 0.51304348 0.54782609 0.51304348
#  0.44347826 0.45217391 0.43478261 0.45217391]
# [0.49565217 0.46956522 0.46956522 0.46956522 0.47368421 0.37719298
#  0.40350877 0.43859649 0.53508772 0.54385965]
# [0.46491228 0.42982456 0.48245614 0.42105263 0.46491228 0.33333333
#  0.35964912 0.5        0.45614035 0.43362832]
# [0.47008547 0.44444444 0.5042735  0.45299145 0.42735043 0.43589744
#  0.48717949 0.46153846 0.35042735 0.47008547]
# **********------------------------------------------------------------------------------------------ 10.0%[0.42477876 0.37168142 0.50892857 0.42857143 0.44642857 0.41964286
#  0.52678571 0.5        0.47321429 0.47321429]
# [0.45132743 0.45132743 0.46902655 0.4159292  0.4159292  0.4159292
#  0.50442478 0.48672566 0.45132743 0.43362832]
# [0.46956522 0.44347826 0.47826087 0.42608696 0.37391304 0.46086957
#  0.40350877 0.49122807 0.44736842 0.40350877]
# [0.45614035 0.4122807  0.5        0.46491228 0.46491228 0.38596491
#  0.42105263 0.47787611 0.4159292  0.38053097]
# [0.4122807  0.45614035 0.46491228 0.46491228 0.50877193 0.44736842
#  0.42982456 0.50442478 0.51327434 0.46017699]
# [0.47413793 0.5        0.43103448 0.47413793 0.50862069 0.3362069
#  0.38793103 0.46551724 0.37068966 0.4173913 ]
# ********************-------------------------------------------------------------------------------- 20.0%[0.47457627 0.47457627 0.51694915 0.4017094  0.45299145 0.53846154
#  0.41025641 0.41025641 0.43589744 0.53846154]
# [0.44347826 0.48695652 0.44347826 0.4        0.46956522 0.42608696
#  0.46086957 0.51754386 0.38596491 0.46491228]
# [0.49122807 0.42105263 0.3245614  0.46491228 0.46491228 0.40707965
#  0.46017699 0.52212389 0.46017699 0.39823009]
# [0.46551724 0.4137931  0.45689655 0.48275862 0.44827586 0.42241379
#  0.51724138 0.48695652 0.42608696 0.43478261]
# [0.44827586 0.48695652 0.45217391 0.53043478 0.46086957 0.46086957
#  0.46956522 0.54782609 0.46086957 0.44347826]
# [0.5042735  0.42735043 0.38461538 0.46153846 0.37606838 0.37606838
#  0.47863248 0.5042735  0.45689655 0.47413793]
# ******************************---------------------------------------------------------------------- 30.0%[0.4957265  0.5042735  0.44444444 0.45299145 0.42735043 0.41025641
#  0.48717949 0.43103448 0.43103448 0.37068966]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-95a51f38a151> in <cell line: 21>()
#      20
#      21 for iter in iterations:
# ---> 22     task(iter[0], iter[1], iter[2])
#
# <ipython-input-41-f17e6a69a1c2> in task(includes, method, max_iter)
#      50         # print(i, end=' ')
#      51         mouth_model = get_mouth_model(includes=includes, method=method)
# ---> 52         nose_model = get_nose_model(includes=includes, method=method)
#      53         eye_model = get_eye_model(includes=includes, method=method)
#      54         mouth_eye_model = get_mouth_eye_model(includes=includes, method=method)
#
# <ipython-input-41-f17e6a69a1c2> in get_nose_model(includes, method)
#       9 def get_nose_model(includes='ns', method='svm'):
#      10     sv_n = Model_Nose(test_size=0.2, low_number_of_images=4, kernel_type = "linear", scale_feature= True, method="rand_forest", category='smile')
# ---> 11     sv_n.generate_train_test_split(category='smile', includes=includes)
#      12     sv_n.train_model(category='smile')
#      13     return sv_n
#
# <ipython-input-19-3ac4f1030ef2> in generate_train_test_split(self, category, includes)
#      48                         #get the features and labels for the image
#      49                         # features = self.get_features(landmark_path + label + "/" + file_name)
# ---> 50                         features = self.feature_extractor.get_features(lines, includes)
#      51
#      52                         #check if the image is in the test set or the train set
#
# <ipython-input-12-5af500b9780e> in get_features(self, lines, includes)
#     181
#     182         # get distance features
# --> 183         dist_features = get_distance_features(lines)
#     184
#     185         # get angle features
#
# <ipython-input-12-5af500b9780e> in get_distance_features(lines)
#      93             ]
#      94
# ---> 95             basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
#      96             nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
#      97             mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
#
# <ipython-input-12-5af500b9780e> in <listcomp>(.0)
#      93             ]
#      94
# ---> 95             basic_shape_dists = [distance(pair[0], pair[1]) for pair in basic_shape_pairs]
#      96             nose_dists = [distance(pair[0], pair[1]) for pair in nose_pairs]
#      97             mouth_dists = [distance(pair[0], pair[1]) for pair in mouth_pairs]
#
# KeyboardInterrupt:
